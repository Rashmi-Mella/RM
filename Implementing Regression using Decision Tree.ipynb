# %% [markdown]
# #  Regression - Decision Tree

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#import all the initial packages

from sklearn import linear_model as lm
import pandas as pd
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt

# %%
#import csv file

con_data = pd.read_excel("Concrete_Data.xls")
cdf_data = con_data.iloc[:, 0:9]
cdf_data
# Out:
#       Cement   Blast Furnace Slag )  Fly Ash   Water    Superplasticizer   \
# 0       540.0                   0.0       0.0    162.0                2.5
# 1       540.0                   0.0       0.0    162.0                2.5
# 2       332.5                 142.5       0.0    228.0                0.0
# 3       332.5                 142.5       0.0    228.0                0.0
# 4       198.6                 132.4       0.0    192.0                0.0
# 5       266.0                 114.0       0.0    228.0                0.0
# 6       380.0                  95.0       0.0    228.0                0.0
# 7       380.0                  95.0       0.0    228.0                0.0
# 8       266.0                 114.0       0.0    228.0                0.0
# 9       475.0                   0.0       0.0    228.0                0.0
# 10      198.6                 132.4       0.0    192.0                0.0
# 11      198.6                 132.4       0.0    192.0                0.0
# 12      427.5                  47.5       0.0    228.0                0.0
# 13      190.0                 190.0       0.0    228.0                0.0
# 14      304.0                  76.0       0.0    228.0                0.0
# 15      380.0                   0.0       0.0    228.0                0.0
# 16      139.6                 209.4       0.0    192.0                0.0
# 17      342.0                  38.0       0.0    228.0                0.0
# 18      380.0                  95.0       0.0    228.0                0.0
# 19      475.0                   0.0       0.0    228.0                0.0
# 20      427.5                  47.5       0.0    228.0                0.0
# 21      139.6                 209.4       0.0    192.0                0.0
# 22      139.6                 209.4       0.0    192.0                0.0
# 23      139.6                 209.4       0.0    192.0                0.0
# 24      380.0                   0.0       0.0    228.0                0.0
# 25      380.0                   0.0       0.0    228.0                0.0
# 26      380.0                  95.0       0.0    228.0                0.0
# 27      342.0                  38.0       0.0    228.0                0.0
# 28      427.5                  47.5       0.0    228.0                0.0
# 29      475.0                   0.0       0.0    228.0                0.0
# ...       ...                   ...       ...      ...                ...
# 1000    141.9                 166.6     129.7    173.5               10.9
# 1001    297.8                 137.2     106.9    201.3                6.0
# 1002    321.3                 164.2       0.0    190.5                4.6
# 1003    366.0                 187.0       0.0    191.3                6.6
# 1004    279.8                 128.9     100.4    172.4                9.5
# 1005    252.1                  97.1      75.6    193.8                8.3
# 1006    164.6                   0.0     150.4    181.6               11.7
# 1007    155.6                 243.5       0.0    180.3               10.7
# 1008    160.2                 188.0     146.4    203.2               11.3
# 1009    298.1                   0.0     107.0    186.4                6.1
# 1010    317.9                   0.0     126.5    209.7                5.7
# 1011    287.3                 120.5      93.9    187.6                9.2
# 1012    325.6                 166.4       0.0    174.0                8.9
# 1013    355.9                   0.0     141.6    193.3               11.0
# 1014    132.0                 206.5     160.9    178.9                5.5
# 1015    322.5                 148.6       0.0    185.8                8.5
# 1016    164.2                   0.0     200.1    181.2               12.6
# 1017    313.8                   0.0     112.6    169.9               10.1
# 1018    321.4                   0.0     127.9    182.5               11.5
# 1019    139.7                 163.9     127.7    236.7                5.8
# 1020    288.4                 121.0       0.0    177.4                7.0
# 1021    298.2                   0.0     107.0    209.7               11.1
# 1022    264.5                 111.0      86.5    195.5                5.9
# 1023    159.8                 250.0       0.0    168.4               12.2
# 1024    166.0                 259.7       0.0    183.2               12.7
# 1025    276.4                 116.0      90.3    179.6                8.9
# 1026    322.2                   0.0     115.6    196.0               10.4
# 1027    148.5                 139.4     108.6    192.7                6.1
# 1028    159.1                 186.7       0.0    175.6               11.3
# 1029    260.9                 100.5      78.3    200.6                8.6
#
#       Coarse Aggregate    Fine Aggregate   Age (day)  \
# 0                 1040.0            676.0         28
# 1                 1055.0            676.0         28
# 2                  932.0            594.0        270
# 3                  932.0            594.0        365
# 4                  978.4            825.5        360
# 5                  932.0            670.0         90
# 6                  932.0            594.0        365
# 7                  932.0            594.0         28
# 8                  932.0            670.0         28
# 9                  932.0            594.0         28
# 10                 978.4            825.5         90
# 11                 978.4            825.5         28
# 12                 932.0            594.0        270
# 13                 932.0            670.0         90
# 14                 932.0            670.0         28
# 15                 932.0            670.0         90
# 16                1047.0            806.9         90
# 17                 932.0            670.0        365
# 18                 932.0            594.0         90
# 19                 932.0            594.0        180
# 20                 932.0            594.0        180
# 21                1047.0            806.9         28
# 22                1047.0            806.9          3
# 23                1047.0            806.9        180
# 24                 932.0            670.0        365
# 25                 932.0            670.0        270
# 26                 932.0            594.0        270
# 27                 932.0            670.0        180
# 28                 932.0            594.0         28
# 29                 932.0            594.0          7
# ...                  ...              ...        ...
# 1000               882.6            785.3         28
# 1001               878.4            655.3         28
# 1002               870.0            774.0         28
# 1003               824.3            756.9         28
# 1004               825.1            804.9         28
# 1005               835.5            821.4         28
# 1006              1023.3            728.9         28
# 1007              1022.0            697.7         28
# 1008               828.7            709.7         28
# 1009               879.0            815.2         28
# 1010               860.5            736.6         28
# 1011               904.4            695.9         28
# 1012               881.6            790.0         28
# 1013               801.4            778.4         28
# 1014               866.9            735.6         28
# 1015               951.0            709.5         28
# 1016               849.3            846.0         28
# 1017               925.3            782.9         28
# 1018               870.1            779.7         28
# 1019               868.6            655.6         28
# 1020               907.9            829.5         28
# 1021               879.6            744.2         28
# 1022               832.6            790.4         28
# 1023              1049.3            688.2         28
# 1024               858.8            826.8         28
# 1025               870.1            768.3         28
# 1026               817.9            813.4         28
# 1027               892.4            780.0         28
# 1028               989.6            788.9         28
# 1029               864.5            761.5         28
#
#       Concrete compressive strength
# 0                         79.986111
# 1                         61.887366
# 2                         40.269535
# 3                         41.052780
# 4                         44.296075
# 5                         47.029847
# 6                         43.698299
# 7                         36.447770
# 8                         45.854291
# 9                         39.289790
# 10                        38.074244
# 11                        28.021684
# 12                        43.012960
# 13                        42.326932
# 14                        47.813782
# 15                        52.908320
# 16                        39.358048
# 17                        56.141962
# 18                        40.563252
# 19                        42.620648
# 20                        41.836714
# 21                        28.237490
# 22                         8.063422
# 23                        44.207822
# 24                        52.516697
# 25                        53.300632
# 26                        41.151375
# 27                        52.124386
# 28                        37.427515
# 29                        38.603761
# ...                             ...
# 1000                      44.611855
# 1001                      53.524711
# 1002                      57.218234
# 1003                      65.909079
# 1004                      52.826962
# 1005                      33.399596
# 1006                      18.033934
# 1007                      37.363394
# 1008                      35.314271
# 1009                      42.644091
# 1010                      40.062003
# 1011                      43.798273
# 1012                      61.235811
# 1013                      40.868690
# 1014                      33.306517
# 1015                      52.426376
# 1016                      15.091251
# 1017                      38.461040
# 1018                      37.265488
# 1019                      35.225329
# 1020                      42.140084
# 1021                      31.875165
# 1022                      41.542308
# 1023                      39.455954
# 1024                      37.917043
# 1025                      44.284354
# 1026                      31.178794
# 1027                      23.696601
# 1028                      32.768036
# 1029                      32.401235
#
# [1030 rows x 9 columns]

# %%
# list the column names

list(cdf_data.columns.values)
# Out:
# ['Cement ',
#  'Blast Furnace Slag )',
#  'Fly Ash ',
#  'Water  ',
#  'Superplasticizer ',
#  'Coarse Aggregate  ',
#  'Fine Aggregate ',
#  'Age (day)',
#  'Concrete compressive strength']

# %%
#As the column names conatains spaces and some extra characters removing them and restoring column names

cdf_data = cdf_data.rename(columns = {'Cement ' : 'Cement', 'Blast Furnace Slag )' : "Blast_Furnace_Slag" ,
                                     'Fly Ash ': 'Fly_Ash' , 'Water  ' : 'Water' ,'Superplasticizer ' : 'Superplasticizer' ,
                                     'Coarse Aggregate  ' : 'Coarse_Aggregate' , 'Fine Aggregate ' : 'Fine_Aggregate' ,
                                     'Age (day)' : 'Age_day' , 'Concrete compressive strength' : 'strength'})

list(cdf_data.columns.values)



type(cdf_data)
# Out:
# ['Cement',
#  'Blast_Furnace_Slag',
#  'Fly_Ash',
#  'Water',
#  'Superplasticizer',
#  'Coarse_Aggregate',
#  'Fine_Aggregate',
#  'Age_day',
#  'strength']
# pandas.core.frame.DataFrame

# %%
#Define Independent(x) and Dependent (y)  varaibles from the above dataset

x = cdf_data[['Cement',
 'Blast_Furnace_Slag',
 'Fly_Ash',
 'Water',
 'Superplasticizer',
 'Coarse_Aggregate',
 'Fine_Aggregate',
 'Age_day']]

y = cdf_data["strength"]

# %%
#Import train_test_split from sklearn model selection to split the data inot train ansd test

from sklearn.model_selection import train_test_split

# %%
# Spilt the Data 

x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size = 0.2, 
                                                    random_state= 100 
                                                    )

# %%
# impprt DecisionTreeRegressor from sklearn tree to perform Decision Tree algorithm

from sklearn.tree import DecisionTreeRegressor

# %%
# Create model object for Decision Tree and choosed random_state as 0

dtreg = DecisionTreeRegressor(random_state = 0)

# %%
#fit the model

dtreg.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
# Predict the values by passing the test data

dtreg_predict = dtreg.predict(x_test)
dtreg_predict
# Out:
# array([67.79617508, 71.29871316, 27.3377234 , 12.5484632 , 39.300132  ,
#        19.69143456, 32.05167081, 15.52631004, 32.9569528 , 27.77209328,
#        42.29245784, 24.84871504, 55.25460664, 29.7508894 , 63.3973182 ,
#        14.94094492, 47.22221124, 14.14391066, 62.5009994 , 41.05346947,
#        52.44154456, 17.59680647, 24.49708228, 31.02642   , 43.6982994 ,
#        37.18245572, 42.919881  , 41.8367142 , 36.80491836, 21.94602108,
#        26.31040416, 24.49708228, 24.40055564, 44.27814872, 64.30053176,
#        25.10382116, 66.42411784, 24.0971862 , 29.72606826, 19.35014394,
#        43.38872468, 23.5111316 , 52.42637609, 48.28400428, 44.284354  ,
#        23.84897484, 29.44751996, 41.68434001, 26.8550902 , 44.51946532,
#        43.25082948, 67.86512268, 62.05284   , 36.3009114 , 66.78067543,
#        60.2946762 , 31.81242264, 24.04616498,  9.99050724, 44.6090972 ,
#        27.62730332,  6.46728488, 11.46598588, 38.32797084, 77.29715436,
#        64.30053176, 46.68441996, 19.10537996, 50.65511224, 34.48758952,
#         8.48744956, 33.00383717, 10.7875415 , 41.24445432, 52.90831981,
#        79.29663476, 49.20100736, 18.91232668, 15.69109481, 53.30063166,
#        13.54130864, 25.11662572, 10.08979178, 24.42813468,  7.83934212,
#        53.52402188, 57.02655996, 37.26548832,  6.90234424, 48.28400428,
#        32.76803638, 12.45193656, 52.1243856 , 43.25082948, 37.404073  ,
#        25.5595648 , 67.86512268, 72.99482412, 39.45595358, 22.94576128,
#        55.89581932, 36.80491836, 14.98920824, 17.22311048, 33.0603742 ,
#        30.88163004, 17.57612219, 40.85834776, 24.84871504, 50.52686971,
#        42.22902605, 49.77327244, 58.79851328, 45.83636448, 25.21689522,
#        29.54897143, 31.35047372, 42.32693164, 35.852752  , 39.32150576,
#        19.10537996, 46.23419213, 26.96540636, 47.96684532, 65.19685056,
#        33.3016908 , 39.42147978, 29.54897143, 43.37700359, 43.89204216,
#        13.18278112, 35.57006684, 10.7875415 , 67.79617508,  9.56165317,
#        42.14008364, 53.52402188, 43.6982994 , 48.15300384, 18.74616296,
#        14.98920824, 13.19657064, 36.83870268, 33.94772981,  2.33180783,
#        21.26343984, 35.22532884, 33.70158688, 55.49592324, 13.62404576,
#        44.86420332, 24.24197616, 42.79577532, 33.71882378, 14.5968964 ,
#        32.39847724,  3.31982694, 11.41427518, 35.57006684, 26.77235308,
#         9.69472204,  8.53571288, 41.20308576, 36.34917472, 35.76312012,
#        26.77235308, 55.89581932,  9.13142014, 26.77235308, 39.2311844 ,
#        23.69660064, 61.88736576, 69.65776028, 56.61907964, 32.83974188,
#        51.4349096 , 22.752708  , 48.97348028, 77.29715436, 10.53588276,
#        47.81378165, 58.79851328, 35.3011712 ,  9.61750072, 42.03045696,
#        23.51802636, 19.98790924, 11.95758227, 67.86512268, 32.10988228,
#        27.67556664, 55.55108132, 18.74616296, 13.29309728, 23.69660064,
#        23.74417449, 31.6469484 , 24.84871504, 46.89815752, 32.83974188,
#        33.39821744, 36.63875464, 39.6103962 ,  9.84965715, 24.53845084,
#        48.79421652])

# %%
# import MSE , MAE amd R2 from sklearn metrics to clculate the same

from sklearn.metrics import mean_squared_error, r2_score , mean_absolute_error

print('Mean Absolute Error:', mean_absolute_error(y_test, dtreg_predict)) 
print('Mean Squared Error:', mean_squared_error(dtreg_predict, y_test))
print('Root Mean Squared Error: ', r2_score(dtreg_predict, y_test))
# Out:
# Mean Absolute Error: 4.077558195177385
# Mean Squared Error: 52.82992965187764
# Root Mean Squared Error:  0.8220510821655271
