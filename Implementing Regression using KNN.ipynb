# %% [markdown]
# # Regression - KNN

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#import all the initial packages

from sklearn import linear_model as lm
import pandas as pd
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt

# %%
#import csv file

con_data = pd.read_excel("Concrete_Data.xls")
cdf_data = con_data.iloc[:, 0:9]
cdf_data
# Out:
#       Cement   Blast Furnace Slag )  Fly Ash   Water    Superplasticizer   \
# 0       540.0                   0.0       0.0    162.0                2.5
# 1       540.0                   0.0       0.0    162.0                2.5
# 2       332.5                 142.5       0.0    228.0                0.0
# 3       332.5                 142.5       0.0    228.0                0.0
# 4       198.6                 132.4       0.0    192.0                0.0
# 5       266.0                 114.0       0.0    228.0                0.0
# 6       380.0                  95.0       0.0    228.0                0.0
# 7       380.0                  95.0       0.0    228.0                0.0
# 8       266.0                 114.0       0.0    228.0                0.0
# 9       475.0                   0.0       0.0    228.0                0.0
# 10      198.6                 132.4       0.0    192.0                0.0
# 11      198.6                 132.4       0.0    192.0                0.0
# 12      427.5                  47.5       0.0    228.0                0.0
# 13      190.0                 190.0       0.0    228.0                0.0
# 14      304.0                  76.0       0.0    228.0                0.0
# 15      380.0                   0.0       0.0    228.0                0.0
# 16      139.6                 209.4       0.0    192.0                0.0
# 17      342.0                  38.0       0.0    228.0                0.0
# 18      380.0                  95.0       0.0    228.0                0.0
# 19      475.0                   0.0       0.0    228.0                0.0
# 20      427.5                  47.5       0.0    228.0                0.0
# 21      139.6                 209.4       0.0    192.0                0.0
# 22      139.6                 209.4       0.0    192.0                0.0
# 23      139.6                 209.4       0.0    192.0                0.0
# 24      380.0                   0.0       0.0    228.0                0.0
# 25      380.0                   0.0       0.0    228.0                0.0
# 26      380.0                  95.0       0.0    228.0                0.0
# 27      342.0                  38.0       0.0    228.0                0.0
# 28      427.5                  47.5       0.0    228.0                0.0
# 29      475.0                   0.0       0.0    228.0                0.0
# ...       ...                   ...       ...      ...                ...
# 1000    141.9                 166.6     129.7    173.5               10.9
# 1001    297.8                 137.2     106.9    201.3                6.0
# 1002    321.3                 164.2       0.0    190.5                4.6
# 1003    366.0                 187.0       0.0    191.3                6.6
# 1004    279.8                 128.9     100.4    172.4                9.5
# 1005    252.1                  97.1      75.6    193.8                8.3
# 1006    164.6                   0.0     150.4    181.6               11.7
# 1007    155.6                 243.5       0.0    180.3               10.7
# 1008    160.2                 188.0     146.4    203.2               11.3
# 1009    298.1                   0.0     107.0    186.4                6.1
# 1010    317.9                   0.0     126.5    209.7                5.7
# 1011    287.3                 120.5      93.9    187.6                9.2
# 1012    325.6                 166.4       0.0    174.0                8.9
# 1013    355.9                   0.0     141.6    193.3               11.0
# 1014    132.0                 206.5     160.9    178.9                5.5
# 1015    322.5                 148.6       0.0    185.8                8.5
# 1016    164.2                   0.0     200.1    181.2               12.6
# 1017    313.8                   0.0     112.6    169.9               10.1
# 1018    321.4                   0.0     127.9    182.5               11.5
# 1019    139.7                 163.9     127.7    236.7                5.8
# 1020    288.4                 121.0       0.0    177.4                7.0
# 1021    298.2                   0.0     107.0    209.7               11.1
# 1022    264.5                 111.0      86.5    195.5                5.9
# 1023    159.8                 250.0       0.0    168.4               12.2
# 1024    166.0                 259.7       0.0    183.2               12.7
# 1025    276.4                 116.0      90.3    179.6                8.9
# 1026    322.2                   0.0     115.6    196.0               10.4
# 1027    148.5                 139.4     108.6    192.7                6.1
# 1028    159.1                 186.7       0.0    175.6               11.3
# 1029    260.9                 100.5      78.3    200.6                8.6
#
#       Coarse Aggregate    Fine Aggregate   Age (day)  \
# 0                 1040.0            676.0         28
# 1                 1055.0            676.0         28
# 2                  932.0            594.0        270
# 3                  932.0            594.0        365
# 4                  978.4            825.5        360
# 5                  932.0            670.0         90
# 6                  932.0            594.0        365
# 7                  932.0            594.0         28
# 8                  932.0            670.0         28
# 9                  932.0            594.0         28
# 10                 978.4            825.5         90
# 11                 978.4            825.5         28
# 12                 932.0            594.0        270
# 13                 932.0            670.0         90
# 14                 932.0            670.0         28
# 15                 932.0            670.0         90
# 16                1047.0            806.9         90
# 17                 932.0            670.0        365
# 18                 932.0            594.0         90
# 19                 932.0            594.0        180
# 20                 932.0            594.0        180
# 21                1047.0            806.9         28
# 22                1047.0            806.9          3
# 23                1047.0            806.9        180
# 24                 932.0            670.0        365
# 25                 932.0            670.0        270
# 26                 932.0            594.0        270
# 27                 932.0            670.0        180
# 28                 932.0            594.0         28
# 29                 932.0            594.0          7
# ...                  ...              ...        ...
# 1000               882.6            785.3         28
# 1001               878.4            655.3         28
# 1002               870.0            774.0         28
# 1003               824.3            756.9         28
# 1004               825.1            804.9         28
# 1005               835.5            821.4         28
# 1006              1023.3            728.9         28
# 1007              1022.0            697.7         28
# 1008               828.7            709.7         28
# 1009               879.0            815.2         28
# 1010               860.5            736.6         28
# 1011               904.4            695.9         28
# 1012               881.6            790.0         28
# 1013               801.4            778.4         28
# 1014               866.9            735.6         28
# 1015               951.0            709.5         28
# 1016               849.3            846.0         28
# 1017               925.3            782.9         28
# 1018               870.1            779.7         28
# 1019               868.6            655.6         28
# 1020               907.9            829.5         28
# 1021               879.6            744.2         28
# 1022               832.6            790.4         28
# 1023              1049.3            688.2         28
# 1024               858.8            826.8         28
# 1025               870.1            768.3         28
# 1026               817.9            813.4         28
# 1027               892.4            780.0         28
# 1028               989.6            788.9         28
# 1029               864.5            761.5         28
#
#       Concrete compressive strength
# 0                         79.986111
# 1                         61.887366
# 2                         40.269535
# 3                         41.052780
# 4                         44.296075
# 5                         47.029847
# 6                         43.698299
# 7                         36.447770
# 8                         45.854291
# 9                         39.289790
# 10                        38.074244
# 11                        28.021684
# 12                        43.012960
# 13                        42.326932
# 14                        47.813782
# 15                        52.908320
# 16                        39.358048
# 17                        56.141962
# 18                        40.563252
# 19                        42.620648
# 20                        41.836714
# 21                        28.237490
# 22                         8.063422
# 23                        44.207822
# 24                        52.516697
# 25                        53.300632
# 26                        41.151375
# 27                        52.124386
# 28                        37.427515
# 29                        38.603761
# ...                             ...
# 1000                      44.611855
# 1001                      53.524711
# 1002                      57.218234
# 1003                      65.909079
# 1004                      52.826962
# 1005                      33.399596
# 1006                      18.033934
# 1007                      37.363394
# 1008                      35.314271
# 1009                      42.644091
# 1010                      40.062003
# 1011                      43.798273
# 1012                      61.235811
# 1013                      40.868690
# 1014                      33.306517
# 1015                      52.426376
# 1016                      15.091251
# 1017                      38.461040
# 1018                      37.265488
# 1019                      35.225329
# 1020                      42.140084
# 1021                      31.875165
# 1022                      41.542308
# 1023                      39.455954
# 1024                      37.917043
# 1025                      44.284354
# 1026                      31.178794
# 1027                      23.696601
# 1028                      32.768036
# 1029                      32.401235
#
# [1030 rows x 9 columns]

# %%
# list the column names
list(cdf_data.columns.values)
# Out:
# ['Cement ',
#  'Blast Furnace Slag )',
#  'Fly Ash ',
#  'Water  ',
#  'Superplasticizer ',
#  'Coarse Aggregate  ',
#  'Fine Aggregate ',
#  'Age (day)',
#  'Concrete compressive strength']

# %%
#As the column names conatains spaces and some extra characters removing them and restoring column names

cdf_data = cdf_data.rename(columns = {'Cement ' : 'Cement', 'Blast Furnace Slag )' : "Blast_Furnace_Slag" ,
                                     'Fly Ash ': 'Fly_Ash' , 'Water  ' : 'Water' ,'Superplasticizer ' : 'Superplasticizer' ,
                                     'Coarse Aggregate  ' : 'Coarse_Aggregate' , 'Fine Aggregate ' : 'Fine_Aggregate' ,
                                     'Age (day)' : 'Age_day' , 'Concrete compressive strength' : 'strength'})

list(cdf_data.columns.values)



type(cdf_data)
# Out:
# ['Cement',
#  'Blast_Furnace_Slag',
#  'Fly_Ash',
#  'Water',
#  'Superplasticizer',
#  'Coarse_Aggregate',
#  'Fine_Aggregate',
#  'Age_day',
#  'strength']
# pandas.core.frame.DataFrame

# %%
#Define Independent(x) and Dependent (y)  varaibles from the above dataset

x = cdf_data[['Cement',
 'Blast_Furnace_Slag',
 'Fly_Ash',
 'Water',
 'Superplasticizer',
 'Coarse_Aggregate',
 'Fine_Aggregate',
 'Age_day']]

y = cdf_data["strength"]

# %%
#Import train_test_split from sklearn model selection to split the data inot train ansd test

from sklearn.model_selection import train_test_split

# %%
# Spilt the Data

x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size = 0.2, 
                                                    random_state= 100 
                                                    )

# %%
# impprt KNeighborsRegressor from sklearn neighbors to perform KNN

from sklearn.neighbors import KNeighborsRegressor

# %%
# Create model object for KNeighborsRegressor and choosed n_neighbors as 5

knn_reg = KNeighborsRegressor(n_neighbors = 5)

# %%
#fit the model

knn_reg.fit(x_train,y_train)
# Out:
# KNeighborsRegressor(algorithm='auto', leaf_size=30, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#           weights='uniform')

# %%
# Predict the values by passing the test data

knn_pred_val = knn_reg.predict(x_test)

# %%
# import MSE , MAE amd R2 from sklearn metrics to clculate the same
from sklearn.metrics import mean_squared_error, r2_score , mean_absolute_error

print('Mean Absolute Error:', mean_absolute_error(y_test, knn_pred_val)) 
print('Mean Squared Error:', mean_squared_error(knn_pred_val, y_test))
print('Root Mean Squared Error: ', r2_score(knn_pred_val, y_test))
# Out:
# Mean Absolute Error: 6.464758203839083
# Mean Squared Error: 74.98888950560902
# Root Mean Squared Error:  0.6028011319651013
